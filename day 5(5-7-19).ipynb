# %% [markdown]
# **Point**
# # markdown basics
# ##### mark
# *hello*
# **hello**
# ***hello***
# *normal
# *google site --[1]:http://www.google.com
#
# -[]option 2
# [2]http://www.google.com
# *google --[google][2]

# %% [markdown]
# ### python basics
# * python version 3.7
# - functional programming
# - object oriented programming
# - script programming

# %%
print("hello Gitam")
# Out:
# hello Gitam

# %%
print("Hello Gitam","@@@")
print("hyderbad")
# Out:
# Hello Gitam @@@
# hyderbad

# %%
print("hello ",end = "")
print("bye")
# Out:
# hello bye

# %% [markdown]
# **Assignment**

# %%
n1=100
print(n1)
# Out:
# 100

# %%
n1=100
a=b=c=20
print(n1)
print(a,b,c)
# Out:
# 100
# 20 20 20

# %% [markdown]
# **Data Types And Conversions**
# - int
# - float
# - string

# %%
a = 100;
s1 = "python"
s2 = "p"
f1=11.78
print(a)
print(s1)
print(s2)
print(f1)
print(type(a))
print(type(s1))
print(type(s2))
print(type(f1))
# Out:
# 100
# python
# p
# 11.78
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'float'>

# %%
i=100
print(type(i))
s1=str(i)
print(type(s1))
s2=float(i)
print(type(s2))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
s1="100"
print(type(s1))
a=int(s1)
print(type(a))
f1=3.9
print(type(f1))
a2=int(f1)
print(type(a2))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
a1=34567899
print(len(str(a1)))
# Out:
# 8

# %%
s1=input("enter your name")
print(s1)
print(type(s1))
# Out:
# enter your nameZubin
# Zubin
# <class 'str'>

# %%
n1=int(input("enter a number"))
print(n1)
# Out:
# enter a number56
# 56

# %%
print(9/4)
print(9//4)
# Out:
# 2.25
# 2

# %%
(((9**9)**9)**9)**10
# Out:
# ...

# %%
a=10
b=5
print(a+b)
print(a-b)
print(a/b)
print(a*b)
print(a**b)
print(a%b)
print(a//b)
# Out:
# 15
# 5
# 2.0
# 50
# 100000
# 0
# 2

# %%
x=1+2**3/4*5
print(x)
# Out:
# 11.0

# %% [markdown]
# - Power
# - division
# - multiplication
# - addition
# - subtraction

# %%
x=10
a1=x>15
print(a1)
# Out:
# False

# %%
print(52+54)
90+51964
# Out:
# 106
# 52054

# %%
n=float(input("enter number"))
if(n%2==0):
    print("even")
elif(n%2!=0):
    print("odd")
else:
    print("INVALID")
# Out:
# enter number4.8967
# odd

# %%
n=int(input("enter a number"))
if n%2==0 and n%5==0:
    print("its divisible by 2 and 5")
else:
    print("its not divisible")
# Out:
# enter a number10
# its divisible by 2 and 5

# %%
n=int(input("enter a number"))
if n==0:
    print("its zero")
elif n>0:
    print("its positive")
elif n<0:
    print("its negative")
# Out:
# enter a number-5
# its negative
